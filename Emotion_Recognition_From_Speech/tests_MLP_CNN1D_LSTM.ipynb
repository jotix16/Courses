# %% [markdown]
# <a href="https://colab.research.google.com/github/DominikVincent/SpeachSpeakerProject/blob/master/tests_MLP_CNN1D_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
#!rm -rf SpeachSpeakerProject

# %% [markdown]
# Pull from Git

# %%
username = 'pernillawikstrom'
password = 'mypassword'
# !git clone https://{username}:{password}@github.com/DominikVincent/SpeachSpeakerProject.git
# Out:
# Cloning into 'SpeachSpeakerProject'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 220 (delta 120), reused 168 (delta 74), pack-reused 0
# Receiving objects: 100% (220/220), 1.25 MiB | 2.91 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# !wget https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip?download=1 -O dataset.zip
# Out:
# --2020-05-11 14:25:48--  https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 208468073 (199M) [application/octet-stream]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 198.81M  38.0MB/s    in 6.2s
#
# 2020-05-11 14:25:55 (32.3 MB/s) - ‘dataset.zip’ saved [208468073/208468073]

# %%
# !mkdir SpeachSpeakerProject/dataset
# !mkdir SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24
# !unzip dataset.zip -d SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24
# Out:
# Archive:  dataset.zip
#    creating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-01-01-01-01-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-01-01-01-02-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-01-01-02-01-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-01-01-02-02-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-02-01-01-01-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-02-01-01-02-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-02-01-02-01-01.wav
#   inflating: SpeachSpeakerProject/dataset/Audio_Speech_Actors_01-24/Actor_01/03-01-02-01-02-02-01.wav
# ...

# %% [markdown]
# Load Data

# %%
# %cd SpeachSpeakerProject/
# Out:
# /content/drive/My Drive/Colab Notebooks/SpeachSpeakerProject

# %%
# !pip3 install soundfile

# %%
# !python3 data_utils/data_loader.py
# Out:
# 1440

# %%
from run_simulations import *
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
test_1()
# Out:
# ALL EMOTIONS & ALL FEATURES
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']
#
# TESTING MLP
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 300)               54300
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2408
# ...
# Total params: 56,708
# Trainable params: 56,708
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...

# %%
EMO_DICT= {0:'neutral', 1:'calm', 2:'happy', 3:'sad', 4:'angry', 5:'fearful', 6:'disgust', 7:'surprised'}

# load data
dl= data_loader.Data_loader()
data = dl.load_data(mfcc=True, chroma=True, mel=True)

# # the mode
m = simulator(data)
observed_emotions = [str(EMO_DICT[idx]) for idx in range(len(EMO_DICT))]
observed_emotions2 = ['calm', 'happy', 'fearful', 'disgust']

# %%
print('\nALL EMOTIONS & [MFCC,MEL] FEATURES')
print(observed_emotions)
print('\nTESTING MLP')
m.run_all(['MLP'], observed_emotions, [['mfcc','mel']])

print('\nALL EMOTIONS & ALL FEATURES')
print('TESTING CNN1D')
m.run_all(['CNN1D'], observed_emotions, [['mfcc','mel']])
# Out:
# ALL EMOTIONS & [MFCC,MEL] FEATURES
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']
#
# TESTING MLP
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 300)               50700
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2408
# ...
# Total params: 53,108
# Trainable params: 53,108
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...

# %%
print('\nALL EMOTIONS & [MFCC,MEL] FEATURES')
print('TESTING LSTM')
m.run_all(['LSTM'], observed_emotions, [['mfcc','mel']])
# Out:
# ALL EMOTIONS & [MFCC,MEL] FEATURES
# TESTING LSTM
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_3 (LSTM)                (None, 300)               577200
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                19264
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64)                256
# _________________________________________________________________
# dense_15 (Dense)             (None, 8)                 520
# ...
# Total params: 597,240
# Trainable params: 597,112
# Non-trainable params: 128
# _________________________________________________________________
# /content/drive/My Drive/Colab Notebooks/SpeachSpeakerProject/run_simulations.py:109: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
print('\nSUBSET OF EMOTIONS & [MFCC,MEL] FEATURES')
print(observed_emotions2)
print('\nTESTING MLP')
m.run_all(['MLP'], observed_emotions2, [['mfcc','mel']])

print('\nALL EMOTIONS & [MFCC,MEL] FEATURES')
print('TESTING CNN1D')
m.run_all(['CNN1D'], observed_emotions2, [['mfcc','mel']])
# Out:
# SUBSET OF EMOTIONS & [MFCC,MEL] FEATURES
# ['calm', 'happy', 'fearful', 'disgust']
#
# TESTING MLP
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 300)               50700
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 1204
# ...
# Total params: 51,904
# Trainable params: 51,904
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Assets written to: backup/MLP_emot4_feat2_model/assets
# ------------------------------------------------------------------------
# Training for fold 1
# Epoch 1/150
# 35/35 [==============================] - 0s 5ms/step - loss: 20.9830 - accuracy: 0.2917 - val_loss: 6.0892 - val_accuracy: 0.3065
# Epoch 2/150
# ...

# %%
print('\nALL EMOTIONS & [MFCC,MEL] FEATURES')
print('TESTING LSTM')
m.run_all(['LSTM'], observed_emotions2, [['mfcc','mel']])

# %%
print('\nALL EMOTIONS & [MEL] FEATURES')
print(observed_emotions)
print('\nTESTING MLP')
m.run_all(['MLP'], observed_emotions, [['mel']])

print('\nALL EMOTIONS & [MEL] FEATURES')
print('TESTING CNN1D')
m.run_all(['CNN1D'], observed_emotions, [['mel']])
# Out:
# ALL EMOTIONS & [MEL] FEATURES
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']
#
# TESTING MLP
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 300)               38700
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 2408
# ...
# Total params: 41,108
# Trainable params: 41,108
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Assets written to: backup/MLP_emot8_feat1_model/assets
# ------------------------------------------------------------------------
# Training for fold 1
# Epoch 1/150
# 65/65 [==============================] - 0s 4ms/step - loss: 2.1506 - accuracy: 0.2230 - val_loss: 1.8464 - val_accuracy: 0.3103
# Epoch 2/150
# ...

# %%
print('\nALL EMOTIONS & [MEL] FEATURES')
print('TESTING LSTM')
m.run_all(['LSTM'], observed_emotions, [['mel']])

# %%
print('\nSUBSET OF EMOTIONS & [MEL] FEATURES')
print(observed_emotions2)
print('\nTESTING MLP')
m.run_all(['MLP'], observed_emotions2, [['mel']])

print('\nALL EMOTIONS & [MEL] FEATURES')
print('TESTING CNN1D')
m.run_all(['CNN1D'], observed_emotions2, [['mel']])
# Out:
# SUBSET OF EMOTIONS & [MEL] FEATURES
# ['calm', 'happy', 'fearful', 'disgust']
#
# TESTING MLP
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 300)               38700
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 1204
# ...
# Total params: 39,904
# Trainable params: 39,904
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Assets written to: backup/MLP_emot4_feat1_model/assets
# ------------------------------------------------------------------------
# Training for fold 1
# Epoch 1/150
# 35/35 [==============================] - 0s 6ms/step - loss: 1.3216 - accuracy: 0.4112 - val_loss: 1.4996 - val_accuracy: 0.3710
# Epoch 2/150
# ...

# %%
print('\nALL EMOTIONS & [MEL] FEATURES')
print('TESTING LSTM')
m.run_all(['LSTM'], observed_emotions2, [['mel']])
# Out:
# ALL EMOTIONS & [MEL] FEATURES
# TESTING LSTM
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 300)               577200
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                19264
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 260
# ...
# Total params: 596,980
# Trainable params: 596,852
# Non-trainable params: 128
# _________________________________________________________________
# /content/drive/My Drive/Colab Notebooks/SpeachSpeakerProject/run_simulations.py:109: RuntimeWarning: invalid value encountered in true_divide
#   X = np.nan_to_num((X - mean)/std, nan=0.0)
# ...
